# %%
import sys
sys.path.append("../src")

from simulation import simulate_normal_returns
from var import compute_var, compute_es

# %%
returns = simulate_normal_returns(0.0005, 0.01, 100000, seed=42)

var_99 = compute_var(returns)
es_99 = compute_es(returns)

var_99, es_99
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 returns = simulate_normal_returns(0.0005, 0.01, 100000, seed=42)
#       3 var_99 = compute_var(returns)
# ----> 4 es_99 = compute_es(returns)
#       6 var_99, es_99
#
# File ~/Desktop/market-risk-engine/notebooks/../src/var.py:16, in compute_es(returns, alpha)
#      11 """
#      12 calculate Value at Risk corresponding to
#      13 alpha confidence level
#      14 """
#      15 x = compute_var(returns, alpha)
# ---> 16 return returns[returns < x].mean()
#
# TypeError: 'float' object is not subscriptable
